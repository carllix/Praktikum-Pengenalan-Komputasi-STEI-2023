# %%
# NIM/Nama  : 19623005/Carlo Angkisan
# Tanggal   : 16 November 2023
# Deskripsi : Problem 2
              # 1. Menghitung banyak data dengan jumlah malam penyewaan minimumnya 1 namun banyaknya review di aplikasi selama 12 bulan tidak 1
              # 2. Menampilkan pemilik rumah dengan banyaknya hari ketersediaan rumah dalam satu tahunnya terbanyak
              # 3. Menghitung banyak rumah di daerah (neighbourhood group) Central Region atau East Region dengan harga rumah per malam di bawah 100
              # 4. Menampilkan banyaknya rumah dengan review per bulan di atas 1 untuk tiap jenis penyediaan ruang
              # 5. Menampilkan 5 nama rumah berdasarkan banyaknya rumah yang disewakan oleh host terbanyak

# %%
# Mengimport library yang dibutuhkan
import pandas as pd

# Membaca data P05-03.csv
df = pd.read_csv('P05-03.csv')
df
# Out:
#             id                                               name    host_id  \
# 0        49091                  COZICOMFORT LONG TERM STAY ROOM 2     266763
# 1        50646                    Pleasant Room along Bukit Timah     227796
# 2        56334                                        COZICOMFORT     266763
# 3        71609                Ensuite Room (Room 1 & 2) near EXPO     367042
# 4        71896                    B&B  Room 1 near Airport & EXPO     367042
# ...        ...                                                ...        ...
# 7902  38105126  Loft 2 pax near Haw Par / Pasir Panjang. Free ...  278109833
# 7903  38108273                         3bedroom luxury at Orchard  238891646
# 7904  38109336    [ Farrer Park ] New City Fringe CBD Mins to MRT  281448565
# 7905  38110493          Cheap Master Room in Central of Singapore  243835202
# 7906  38112762  Amazing room with private bathroom walk to Orc...   28788520
#
# ...

# %%
# 1. Menghitung banyak data dengan jumlah malam penyewaan minimumnya 1 namun banyaknya review di aplikasi selama 12 bulan tidak 1
print(f"Banyak data dengan jumlah malam penyewaan minimumnya 1 namun banyaknya review di aplikasi selama 12 bulan tidak 1 adalah {len(df.loc[(df['minimum_nights']==1) & (df['number_of_reviews']!=1)])}")
# Out:
# Banyak data dengan jumlah malam penyewaan minimumnya 1 namun banyaknya review di aplikasi selama 12 bulan tidak 1 adalah 1841

# %%
# 2. Menampilkan pemilik rumah dengan banyaknya hari ketersediaan rumah dalam satu tahunnya terbanyak
print(f"Pemilik rumah dengan banyaknya hari ketersediaan rumah dalam satu tahunnya terbanyak adalah {df.loc[df['availability_365'].idxmax()]['host_name']}")
# Out:
# Pemilik rumah dengan banyaknya hari ketersediaan rumah dalam satu tahunnya terbanyak adalah Francesca

# %%
# 3. Menghitung banyak rumah di daerah (neighbourhood group) Central Region atau East Region dengan harga rumah per malam di bawah 100

print(f"Banyak rumah di daerah (neighbourhood group) Central Region atau East Region dengan harga rumah per malam di bawah 100 adalah {len(df.loc[((df['neighbourhood_group']=='Central Region')|(df['neighbourhood_group']=='East Region')) & (df['price']<100)])}")
# Out:
# Banyak rumah di daerah (neighbourhood group) Central Region atau East Region dengan harga rumah per malam di bawah 100 adalah 2429

# %%
# 4. Menampilkan banyaknya rumah dengan review per bulan di atas 1 untuk tiap jenis penyediaan ruang
reviews_per_month_diatas1 = df.loc[df['reviews_per_month']>1]
reviews_per_month_diatas1['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    873
# Private room       681
# Shared room         67
# Name: count, dtype: int64

# %%
# 5. Menampilkan 5 nama rumah berdasarkan banyaknya rumah yang disewakan oleh host terbanyak
df.sort_values(['calculated_host_listings_count'], ascending=False)[:5]
# Out:
#             id                                               name   host_id  \
# 3107  21151992  Cosy 2BR pent hse at Jurong/Clementi/Pasir Pan...  66406177
# 5950  32388996   CBD Spacious Apt. 2min walk to Tanjong Pagar MRT  66406177
# 5258  30004765       Stylish 1BR Located 7 mins from Tg Pagar MRT  66406177
# 5105  29522835        Minimalist, Comfortable 2BR in Central East  66406177
# 5104  29522642          Capacious  Homely 2BR APT in Orchard Area  66406177
#
#      host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# 3107       Jay         West Region       Clementi   1.31639  103.75721
# 5950       Jay      Central Region  Downtown Core   1.27594  103.84512
# 5258       Jay      Central Region  Downtown Core   1.27439  103.84458
# 5105       Jay      Central Region        Geylang   1.31874  103.88261
# 5104       Jay      Central Region         Newton   1.30846  103.82857
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# ...
